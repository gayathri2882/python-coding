# %% [markdown]
# <a href="https://colab.research.google.com/github/gayathri2882/python-coding/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=int(input("Enter no of monkeys:"))
k=int(input("Enter no of bananas eatable by single monkey:"))
j=int(input("Enter no of peanuts eatable by single monkey:"))
m=int(input("Enter total no of bananas:"))
p=int(input("Enter total no of peanuts:"))
monkeys=m//k +p//j
print("Monkey came down are:",monkeys)
left = n-monkeys
if(m%k!=p%j):
    left=n-1
print("No of monkeys left:",left)
# Out:
# Enter no of monkeys:20
# Enter no of bananas eatable by single monkey:2
# Enter no of peanuts eatable by single monkey:3
# Enter total no of bananas:12
# Enter total no of peanuts:12
# Monkey came down are: 10
# No of monkeys left: 10

# %%
print("Using Temp")
a,b=10,5
temp=a
a=b
b=temp
print(a,b)
print("Using ,")
a,b=10,5
a,b=b,a
print(a,b)
print("Using + and -")
a,b=10,5
a=a+b
b=a-b
a=a-b
print(a,b)
print("Using ^")
a,b=10,5
a=a^b
b=a^b
a=a^b
print(a,b)
# Out:
# Using Temp
# 5 10
# Using ,
# 5 10
# Using + and -
# 5 10
# Using ^
# 5 10

# %%
n=int(input("Enter max no. of candies:"))
k=int(input("Enter min no. of candies:"))
con=1
r=n
while(con==1):
  m=int(input("Enter amount of candies needed:"))
  if(m>n):
    print("invalid")
  else:
    r=r-m
    if(r<=k):
      r=n
    print("Sold=",m)
    print("Remaining=",r)
    con=int(input("press 0 to exit and 1 to continue:"))
# Out:
# Enter max no. of candies:10
# Enter min no. of candies:5
# Enter amount of candies needed:3
# Sold= 3
# Remaining= 7
# press 0 to exit and 1 to continue:0

# %%
a=int(input("Enter list size:"))
list=[]
for i in range(a):
  b=int(input("Enter the elements in the list"))
  list.append(b)
print("LIST:",list)
# Out:
# Enter list size:3
# Enter the elements in the list7
# Enter the elements in the list8
# Enter the elements in the list9
# LIST: [7, 8, 9]

# %%
n = int(input("Enter number of elements: "))
a = []
for i in range(n):
    a.append(int(input("Enter element: ")))
print("Largest element:", max(a))
# Out:
# Enter number of elements: 4
# Enter element: 5
# Enter element: 4
# Enter element: 3
# Enter element: 5
# Largest element: 5

# %%
n=int(input("enter the number of elements"))
a=[]
for i in range (n):
  m = int(input("enter the element"))
  a.append(m)

  print(a)
print("the smallest element is",min(a))
# Out:
# enter the number of elements3
# enter the element2
# [2]
# enter the element3
# [2, 3]
# enter the element4
# [2, 3, 4]
# the smallest element is 2

# %%
l=[]
n=int(input("Enter the number of elements: "))
for i in range(n):
  a=int(input("Enter element: "))
  l.append(a)
print("SUM :",sum(l))
# Out:
# Enter the number of elements: 2
# Enter element: 5
# Enter element: 6
# SUM : 11

# %%
list=[]
n=int(input("Enter the number of elements: "))
for i in range(n):
  a=int(input("Enter element: "))
  list.append(a)
print('Reversed Array',list[::-1])
# Out:
# Enter the number of elements: 3
# Enter element: 3
# Enter element: 4
# Enter element: 5
# Reversed Array [5, 4, 3]

# %%
l=[]
n=int(input("Enter the number of elements: "))
for i in range(n):
  a=int(input("Enter element: "))
  l.append(a)
a=int(input("Enter the element to be searched "))
if a in l:
  print("Element exists")
else:
  print("Element does not exist")
# Out:
# Enter the number of elements: 4
# Enter element: 2
# Enter element: 3
# Enter element: 5
# Enter element: 6
# Enter the element to be searched 5
# Element exists

# %%
n= int(input("enter the number of element:"))
a =[]
for i in range (n):
    m=int(input("enter the element"))
    a.append(m)
print("list:",a)
x= int(input("enter the number to count"))
print(x, "occur" ,a.count(x), "times")
# Out:
# enter the number of element:4
# enter the element2
# enter the element3
# enter the element6
# enter the element7
# list: [2, 3, 6, 7]
# enter the number to count3
# 3 occur 1 times

# %%
n = int(input("Enter the number of elements: "))
a = []
for i in range(n):
    m = int(input("Enter the element: "))
    a.append(m)
print("List:", a)
largest = second = float('-inf')
for num in a:
    if num > largest:
        second = largest
        largest = num
    elif num > second and num != largest:
        second = num
print("The largest is", largest)
print("The second largest is", second)
# Out:
# Enter the number of elements: 5
# Enter the element: 1
# Enter the element: 2
# Enter the element: 3
# Enter the element: 4
# Enter the element: 5
# List: [1, 2, 3, 4, 5]
# The largest is 5
# The second largest is 4

# %%
n = int(input("Enter the number of elements: "))
a = []
for i in range(n):
    m = int(input("Enter the element: "))
    a.append(m)
print("Original list:", a)
result = []
for num in a:
    if num not in result:
        result.append(num)
print("List after removing duplicates:", result)
# Out:
# Enter the number of elements: 5
# Enter the element: 3
# Enter the element: 4
# Enter the element: 5
# Enter the element: 6
# Enter the element: 7
# Original list: [3, 4, 5, 6, 7]
# List after removing duplicates: [3, 4, 5, 6, 7]

# %%
n=int(input("enter the number of elements:"))
a =[]
for i in range(n):
  m=int(input("enter the element:"))
  a.append(m)
print("original list:", a)
a.sort()
print("sorted list(asending):" , a)
# Out:
# enter the number of elements:5
# enter the element:2
# enter the element:3
# enter the element:7
# enter the element:4
# enter the element:1
# original list: [2, 3, 7, 4, 1]
# sorted list(asending): [1, 2, 3, 4, 7]

# %%
n = int(input("Enter number of elements: "))
arr = [int(x) for x in input("Enter elements: ").split()]
print("array:",arr)
# Out:
# Enter number of elements: 4
# Enter elements: 3 4 5 6
# array: [3, 4, 5, 6]

# %%
a=[]
n=int(input("Enter the number of elements: "))
for i in range(n):
  a.append(int(input("Enter the element: ")))
  print("List=",a)
print("Normal slicing without range",a[:])
print("slicing range in leftside",a[1:])
print("slicing with range in both side",a[2:4])
print("slicing with range in rightside",a[:5])
print("slicing using step",a[1:7:3])
# Out:
# Enter the number of elements: 5
# Enter the element: 2
# List= [2]
# Enter the element: 3
# List= [2, 3]
# Enter the element: 4
# List= [2, 3, 4]
# Enter the element: 5
# List= [2, 3, 4, 5]
# Enter the element: 6
# List= [2, 3, 4, 5, 6]
# Normal slicing without range [2, 3, 4, 5, 6]
# slicing range in leftside [3, 4, 5, 6]
# slicing with range in both side [4, 5]
# slicing with range in rightside [2, 3, 4, 5, 6]
# slicing using step [3, 6]

# %%
r = int(input("Enter number of rats: "))
unit = int(input("Enter the amount of food each rat consumes: "))
n = int(input("Enter number of houses: "))
arr =  __builtins__.list(map(int,input("enter amount of food present in each house: ").split()))

if arr is None or n==0:
    print(-1)
else:
    required = r * unit
    total_food=sum(arr)
    if total_food < required:
      print(0)
    else:
      total=0
      houses=0
      for food in arr:
        total+=food
        houses+=1
        if total>=required:
          break
      print("no of houses",houses)
# Out:
# Enter number of rats: 7
# Enter the amount of food each rat consumes: 2
# Enter number of houses: 8
# enter amount of food present in each house: 2 8 3 5 7 4 1 2
# no of houses 4

# %%
n=input("enter a string")
print("input string",n)
print("Reversed string")
print(n[::-1])
# Out:
# enter a stringapple
# input string apple
# Reversed string
# elppa

# %%
n=int(input("enter a number"))
rev=0
while n>0:
  num=n%10
  rev=rev*10+num
  n=n//10
print("rev",rev)
# Out:
# enter a number25
# rev 52

# %%
n=int(input("enter the number:"))
s=0
while n>0:
  r=n%10
  s=s+r
  n=n//10
print("sum:",s)
# Out:
# enter the number:43
# sum: 7

# %%
n=int(input("enter a number:"))
l=0
while n>0:
  r=n%10
  if r>l:
    l=r
    n=n//10
    print("largest number",l)
# Out:
# enter a number:345
# largest number 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_968/3577091306.py in <cell line: 0>()
#       1 n=int(input("enter a number:"))
#       2 l=0
# ----> 3 while n>0:
#       4   r=n%10
#       5   if r>l:
#
# KeyboardInterrupt:

# %%
n=int(input("Enter a number:"))
n1=n
r=0
while n>0:
  a=n%10
  r=r*10+a
  n=n//10
if r==n1:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Enter a number:121
# Palindrome

# %%
x=input("Enter a string:")
if x==x[::-1]:
  print("string is palindrome")
else:
  print("String is not palindrome")
# Out:
# Enter a string:amma
# string is palindrome

# %%
s1=input("Enter the first string: ")
s2=input("Enter the second string: ")
if sorted(s1)==sorted(s2):
  print("Anagram")
else:
  print("Not Anagram")
# Out:
# Enter the first string: gayu
# Enter the second string: gayu
# Anagram

# %%
s=input("Enter string :")
print("With build-in function",len(s))
count=0
for i in s:
   count+=1
print("Without build-in",count)
# Out:
# Enter string :gathy
# With build-in function 5
# Without build-in 5

# %%
s=input("Enter string :")
result =""
for ch in s:
  if ch not in result:
    result = result +ch
print("After removing duplicates: ",result)
# Out:
# Enter string :banana
# After removing duplicates:  ban

# %%
s=input("Ënter a string:")
v=0
c=0
for i in s:
  if(i in "aeiouAEIOU"):
    v+=1
  else:
    c+=1
print("No. of vowels:",v)
print("No of consonants:",c)
# Out:
# Ënter a string:ice cream
# No. of vowels: 4
# No of consonants: 5

# %%
n=int(input("Enter the value :"))
b=bin(n)[2:]
print("Binary number is :",b)
b=b.replace('0','y')
b=b.replace('1','0')
b=b.replace('y','1')
print(int(b,2))
# Out:
# Enter the value :10
# Binary number is : 1010
# 5
